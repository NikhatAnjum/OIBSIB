# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv(r"C:\Users\syeda\OneDrive\Desktop\Advertising.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.where(pd.notnull(df),' ')
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# # Data Analysis

# %%
df.head(10)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 5           6    8.7   48.9       75.0    7.2
# 6           7   57.5   32.8       23.5   11.8
# 7           8  120.2   19.6       11.6   13.2
# 8           9    8.6    2.1        1.0    4.8
# 9          10  199.8    2.6       21.2   10.6

# %%
data=df.where(pd.notnull(df),' ')

# %%
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
data.head(30)
# Out:
#     Unnamed: 0     TV  Radio  Newspaper  Sales
# 0            1  230.1   37.8       69.2   22.1
# 1            2   44.5   39.3       45.1   10.4
# 2            3   17.2   45.9       69.3    9.3
# 3            4  151.5   41.3       58.5   18.5
# 4            5  180.8   10.8       58.4   12.9
# 5            6    8.7   48.9       75.0    7.2
# 6            7   57.5   32.8       23.5   11.8
# 7            8  120.2   19.6       11.6   13.2
# 8            9    8.6    2.1        1.0    4.8
# 9           10  199.8    2.6       21.2   10.6
# 10          11   66.1    5.8       24.2    8.6
# 11          12  214.7   24.0        4.0   17.4
# 12          13   23.8   35.1       65.9    9.2
# 13          14   97.5    7.6        7.2    9.7
# 14          15  204.1   32.9       46.0   19.0
# 15          16  195.4   47.7       52.9   22.4
# 16          17   67.8   36.6      114.0   12.5
# 17          18  281.4   39.6       55.8   24.4
# 18          19   69.2   20.5       18.3   11.3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.shape
# Out:
# (200, 5)

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
data = data.drop(columns=['Unnamed: 0'])
print(data)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
data['Sales'].value_counts()
# Out:
# 9.7     5
# 11.7    4
# 12.9    4
# 15.9    4
# 20.7    3
#        ..
# 17.0    1
# 18.3    1
# 22.3    1
# 14.0    1
# 25.5    1
# Name: Sales, Length: 121, dtype: int64

# %% [markdown]
# # Preprocessing the dataset

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# # Exploratory DataAnalysis

# %%
data['TV'].hist()
# Out:
# <Axes: >

# %%
data['Radio'].hist()
# Out:
# <Axes: >

# %%
data['Newspaper'].hist()
# Out:
# <Axes: >

# %%
data['Sales'].hist()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12, 8))

columns = {0: "TV", 1: "Radio", 2: "Newspaper", 3: "Sales"}

for plot, col_name in columns.items():
    plt.subplot(2, 2, plot + 1)
    sns.boxplot(data=df[col_name],palette="pastel")
    plt.xlabel(col_name)
    plt.title("Outliers in {} feature".format(col_name))

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 5))

columns = {0: "TV", 1: "Radio", 2: "Newspaper"}

for plot, col_name in columns.items():
    plt.subplot(1, 3, plot + 1)
    sns.distplot(x=df[col_name],hist=False, label= col_name)
    sns.distplot(x=df["Sales"],hist = False,label= "Sales")
    plt.xlabel("{} VS Sales".format(col_name))
    plt.title("Distribution plot {} VS Sales".format(col_name))
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Visualization

# %%
dt = pd.read_csv(r"C:\Users\syeda\OneDrive\Desktop\Advertising.csv")
dt
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
sns.pairplot(data = df,x_vars=["TV", "Radio", "Newspaper"], y_vars="Sales", kind="reg",palette="pastel")
plt.show()

# %%
plt.figure(figsize=(15, 5))

columns = {0: "TV", 1: "Radio", 2: "Newspaper"}

for plot, col_name in columns.items():
    plt.subplot(1, 3, plot + 1)
    sns.scatterplot(x=df[col_name],y=df["Sales"], label= col_name,palette="pastel")
    plt.xlabel("{} VS Sales".format(col_name))
    plt.title("Scatter plot: {} VS Sales".format(col_name))
    plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_19416\348260033.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=df[col_name],y=df["Sales"], label= col_name,palette="pastel")
# C:\Users\syeda\AppData\Local\Temp\ipykernel_19416\348260033.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=df[col_name],y=df["Sales"], label= col_name,palette="pastel")
# C:\Users\syeda\AppData\Local\Temp\ipykernel_19416\348260033.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x=df[col_name],y=df["Sales"], label= col_name,palette="pastel")

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df,x="TV",y="Sales",style="Radio",size="Newspaper",palette="pastel")
plt.xlabel("TV")
plt.ylabel("Sales")
plt.title("Relationship between TV and Sales")
plt.show()
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_19416\3726856719.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(data=df,x="TV",y="Sales",style="Radio",size="Newspaper",palette="pastel")

# %%
X = df.drop(columns ="Sales",axis=1)

# %%
y=df["Sales"]

# %%
from sklearn.preprocessing import MinMaxScaler,LabelEncoder,StandardScaler

le = LabelEncoder()
y= le.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,D,test_size=0.2,random_state=42)

# %%
scaler = MinMaxScaler()
scaler.fit(X_train,y_train)
# Out:
# MinMaxScaler()

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Model Training

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
models = [("Linear Regression", LinearRegression()),("Ridge Regression",Ridge()),("Lasso Regression",Lasso())]

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score

for name, model in models:
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)

    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    cv_scores = cross_val_score(model, X_train_scaled, y_train, cv=5, scoring='r2')

    print("{}".format(name))
    print("Mean Squared Error: {}".format(mse))
    print("R2 Score: {}".format(r2))
    print("Cross-Validation R2: {}".format(cv_scores.mean()))

    plt.figure(figsize=(10, 6))
    plt.plot(np.arange(len(y_test)), y_test, label='Actual Trend')
    plt.plot(np.arange(len(y_test)), y_pred, label='Predicted Trend')
    plt.xlabel('Data Index')
    plt.ylabel('Trend')
    plt.title(f'{name}: Actual Trend vs. Predicted Trend')
    plt.legend()
    plt.show()
    print()
# Out:
# Linear Regression
# Mean Squared Error: 3.199004468588906
# R2 Score: 0.898648915141708
# Cross-Validation R2: 0.8582529864194667
# Ridge Regression
# Mean Squared Error: 3.5251989363650305
# R2 Score: 0.8883143990419332
# Cross-Validation R2: 0.8541809250201788
# Lasso Regression
# Mean Squared Error: 27.833508953208337
# R2 Score: 0.11817680921684204
# Cross-Validation R2: -0.07480543323377124

# %% [markdown]
# # Model Testing

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
sns.pairplot(dt)

# %%
dt.hist(bins=30,figsize=(15,8))
plt.suptitle('Features of Distribution')
# Out:
# Text(0.5, 0.98, 'Features of Distribution')

# %%
dt.boxplot(figsize=(15,6))
plt.suptitle('BoxPlot')
# Out:
# Text(0.5, 0.98, 'BoxPlot')

# %%
plt.figure(figsize=(12,6))
sns.distplot(x=dt['TV'],kde=True)
plt.title('TV-Feature Distribution')
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_19416\2333430406.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=dt['TV'],kde=True)
# Text(0.5, 1.0, 'TV-Feature Distribution')

# %%
plt.figure(figsize=(12,6))
sns.distplot(x=dt['Radio'],kde=True)
plt.title('Radio: Feature Distribution')
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_19416\2472043365.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=dt['Radio'],kde=True)
# Text(0.5, 1.0, 'Radio: Feature Distribution')

# %%
plt.figure(figsize=(12,6))
sns.distplot(x=dt['Newspaper'],kde=True)
plt.title('Newspaper-- Feature Distribution')
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_19416\2298261617.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=dt['Newspaper'],kde=True)
# Text(0.5, 1.0, 'Newspaper-- Feature Distribution')

# %%
plt.figure(figsize=(12,6))
sns.distplot(x=dt['Sales'],kde=True)
plt.title('Sales Feature Distribution (Target Variable)')
# Out:
# C:\Users\syeda\AppData\Local\Temp\ipykernel_19416\3487811357.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=dt['Sales'],kde=True)
# Text(0.5, 1.0, 'Sales Feature Distribution (Target Variable)')

# %% [markdown]
# # Heapmap

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data=dt.corr(),annot=True,linecolor='white',linewidths=0.2)
plt.title('Heatmap of DataFrame')
# Out:
# Text(0.5, 1.0, 'Heatmap of DataFrame')

# %%
plt.figure(figsize=(12,5))
df.corr()['Sales'].sort_values().plot(kind='bar')
plt.xlabel('Features')
plt.ylabel('Correlation Value')
plt.title('Correlation Plot of All Features')
# Out:
# Text(0.5, 1.0, 'Correlation Plot of All Features')

# %% [markdown]
# # Conclusions:

# %% [markdown]
# ==> Tv has the maximum advertisement
# ==> The gap between the tv advertisement for sales is less.
# ==> The gap in both Radio and Newspaper advertisement sales is more than TV.
# ==> Here we used some of the Regression models.
